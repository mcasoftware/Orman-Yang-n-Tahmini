# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import warnings
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import scale
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error ,r2_score
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn import model_selection
from sklearn.linear_model import Ridge ,Lasso,ElasticNet
import statsmodels.api as sm
from warnings import filterwarnings
filterwarnings('ignore')
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
from sklearn.linear_model import RidgeCV, LassoCV, ElasticNetCV

# %%
df=pd.read_csv("forestfires.csv")
df= df.iloc[:,1:len(df)]
df.head()
# Out:
#    Y month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  5   mar  fri  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  4   oct  tue  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  4   oct  sat  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  6   mar  fri  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  6   mar  sun  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %%
X=df.drop('area', axis=1)
y=df[["area"]]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Read the CSV file
df = pd.read_csv("./forestfires.csv")  # Ensure the file path is correct
df = df.dropna()

# Create dummy variables for 'month' and 'day'
dms = pd.get_dummies(df[['month', 'day']])

# Define target variable
y = df["area"]

# Drop 'area', 'month', and 'day' from X
X_ = df.drop(['area', 'month', 'day'], axis=1).astype('float')

# Concatenate dummy variables with X
X = pd.concat([X_, dms], axis=1)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=99)

# %%
knn_model= KNeighborsRegressor().fit(X_train,y_train)

# %%
knn_model
# Out:
# KNeighborsRegressor()

# %%
#komşu sayısı
knn_model.n_neighbors
# Out:
# 5

# %%
#metrik
knn_model.metric
# Out:
# 'minkowski'

# %%
#knn_model nesnesinin içinden ne alabiliriz?
dir(knn_model)
# Out:
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__sklearn_clone__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_build_request_for_signature',
#  '_check_algorithm_metric',
#  '_check_feature_names',
#  '_check_n_features',
#  '_doc_link_module',
#  '_doc_link_template',
#  '_doc_link_url_param_generator',
#  '_estimator_type',
#  '_fit',
#  '_fit_X',
#  '_fit_method',
#  '_get_default_requests',
#  '_get_doc_link',
#  '_get_metadata_request',
#  '_get_param_names',
#  '_get_tags',
#  '_kneighbors_reduce_func',
#  '_more_tags',
#  '_parameter_constraints',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
#  '_tree',
#  '_validate_data',
#  '_validate_params',
#  '_y',
#  'algorithm',
#  'effective_metric_',
#  'effective_metric_params_',
#  'feature_names_in_',
#  'fit',
#  'get_metadata_routing',
#  'get_params',
#  'kneighbors',
#  'kneighbors_graph',
#  'leaf_size',
#  'metric',
#  'metric_params',
#  'n_features_in_',
#  'n_jobs',
#  'n_neighbors',
#  'n_samples_fit_',
#  'p',
#  'predict',
#  'radius',
#  'score',
#  'set_params',
#  'set_score_request',
#  'weights']

# %%
#bağımlı değişkenin değer tahmini
knn_model.predict(X_test) [0:5]
# Out:
# array([ 0.434,  5.578, 13.98 ,  2.638,  0.224])

# %%
y_pred = knn_model.predict(X_test)

# %%
#test hatası
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 47.68709692955979

# %%
knn_model
# Out:
# KNeighborsRegressor()

# %%
#
RMSE=[]
for k in range (10):
    k=k+1
    knn_model=KNeighborsRegressor(n_neighbors =k).fit(X_train, y_train)
    y_pred=knn_model.predict(X_test)
    rmse=np.sqrt(mean_squared_error(y_test,y_pred))
    RMSE.append(rmse)
    print ("k=", k, "için RMSE değeri:",rmse)
# Out:
# k= 1 için RMSE değeri: 147.09120103632196
# k= 2 için RMSE değeri: 91.02932212923312
# k= 3 için RMSE değeri: 64.73064560028008
# k= 4 için RMSE değeri: 53.43656821049967
# k= 5 için RMSE değeri: 47.68709692955979
# k= 6 için RMSE değeri: 44.261558338342105
# k= 7 için RMSE değeri: 42.16662134238064
# k= 8 için RMSE değeri: 40.94913119705067
# k= 9 için RMSE değeri: 40.7677763196545
# k= 10 için RMSE değeri: 40.29951665304723

# %%
#GridSearchCV test hatası

# %%
knn_params= {"n_neighbors":np.arange(1,30,1)}

# %%
knn=KNeighborsRegressor()

# %%
knn_cv_model=GridSearchCV(knn, knn_params,cv=10).fit(X_train, y_train)

# %%
knn_cv_model.best_params_
# Out:
# {'n_neighbors': 29}

# %%
#final model
knn_tuned= KNeighborsRegressor(n_neighbors=knn_cv_model.best_params_["n_neighbors"]).fit(X_train,y_train)

# %%
y_pred = knn_model.predict(X_test)

# %%
#final modelinin test hatası
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 40.29951665304723
